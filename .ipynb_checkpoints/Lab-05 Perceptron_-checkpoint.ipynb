# %% [markdown]
# Linear Perceptron은 NOT, AND, OR 연산이 가능하지만, XOR 연산에 대해 예측을 잘 하지 못한다.

# %% [markdown]
# # overview

# %%
import torch
torch.manual_seed(777)

device = 'cuda' if torch.cuda.is_available() else 'cpu'

if device == 'cuda':
    torch.cuda.manual_seed_all(777)

# %% [markdown]
# ## Not

# %%
X = torch.FloatTensor([[0], 
                       [1]])
Y = torch.FloatTensor([[1],
                      [0]])

linear = torch.nn.Linear(1, 1)
sigmoid = torch.nn.Sigmoid()

model = torch.nn.Sequential(linear, 
                            sigmoid)

criterion = torch.nn.BCELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

for step in range(10001):
    optimizer.zero_grad()
    hypothesis = model(X)

    # cost/loss function
    cost = criterion(hypothesis, Y)
    cost.backward()
    optimizer.step()

    if step % 1000 == 0:
        print(step, cost.item())
        
# Accuracy computation
# True if hypothesis>0.5 else False
with torch.no_grad():
    hypothesis = model(X)
    predicted = (hypothesis > 0.5).float()
    accuracy = (predicted == Y).float().mean()
    print('\nHypothesis: ', hypothesis.detach().cpu().numpy(), 
          '\nCorrect: ', predicted.detach().cpu().numpy(), 
          '\nAccuracy: ', accuracy.item() * 100, '%')
# Out:
# 0 1.047511339187622
# 1000 0.054459936916828156
# 2000 0.026588747277855873
# 3000 0.017490513622760773
# 4000 0.013009527698159218
# 5000 0.010348819196224213
# 6000 0.008588391356170177
# 7000 0.007338150404393673
# 8000 0.006404797546565533
# 9000 0.005681491922587156
# 10000 0.00510468939319253
#
# Hypothesis:  [[0.9938903 ]
#  [0.00407149]]
# Correct:  [[1.]
#  [0.]]
# Accuracy:  100.0 %

# %% [markdown]
# ### Sigmoid

# %% [markdown]
# ### BCELoss

# %% [markdown]
# ## AND

# %%
X = torch.FloatTensor([[0, 0], [0, 1], [1, 0], [1, 1]])
Y = torch.FloatTensor([[0], [0], [0], [1]])

linear = torch.nn.Linear(2, 1)
sigmoid = torch.nn.Sigmoid()

model = torch.nn.Sequential(linear, sigmoid)

criterion = torch.nn.BCELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

for step in range(10001):
    optimizer.zero_grad()
    hypothesis = model(X)

    # cost/loss function
    cost = criterion(hypothesis, Y)
    cost.backward()
    optimizer.step()

    if step % 1000 == 0:
        print(step, cost.item())
        
# Accuracy computation
# True if hypothesis>0.5 else False
with torch.no_grad():
    hypothesis = model(X)
    predicted = (hypothesis > 0.5).float()
    accuracy = (predicted == Y).float().mean()
    print('\nHypothesis: ', hypothesis.detach().cpu().numpy(), 
          '\nCorrect: ', predicted.detach().cpu().numpy(), 
          '\nAccuracy: ', accuracy.item() * 100, '%')
# Out:
# 0 0.684533953666687
# 1000 0.14358986914157867
# 2000 0.08167922496795654
# 3000 0.05656496807932854
# 4000 0.04307448863983154
# 5000 0.03470040112733841
# 6000 0.029014136642217636
# 7000 0.024908579885959625
# 8000 0.0218089297413826
# 9000 0.01938801072537899
# 10000 0.01744607836008072
#
# Hypothesis:  [[1.2511369e-05]
#  [2.0272110e-02]
#  [2.0272110e-02]
#  [9.7160691e-01]]
# Correct:  [[0.]
#  [0.]
#  [0.]
#  [1.]]
# Accuracy:  100.0 %

# %% [markdown]
# ## OR

# %%
X = torch.FloatTensor([[0, 0], [0, 1], [1, 0], [1, 1]])
Y = torch.FloatTensor([[0], [1], [1], [1]])

linear = torch.nn.Linear(2, 1)
sigmoid = torch.nn.Sigmoid()

model = torch.nn.Sequential(linear, sigmoid)

criterion = torch.nn.BCELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

for step in range(10001):
    optimizer.zero_grad()
    hypothesis = model(X)

    # cost/loss function
    cost = criterion(hypothesis, Y)
    cost.backward()
    optimizer.step()

    if step % 1000 == 0:
        print(step, cost.item())
        
# Accuracy computation
# True if hypothesis>0.5 else False
with torch.no_grad():
    hypothesis = model(X)
    predicted = (hypothesis > 0.5).float()
    accuracy = (predicted == Y).float().mean()
    print('\nHypothesis: ', hypothesis.detach().cpu().numpy(), 
          '\nCorrect: ', predicted.detach().cpu().numpy(), 
          '\nAccuracy: ', accuracy.item() * 100, '%')
# Out:
# 0 0.6071336269378662
# 1000 0.08814549446105957
# 2000 0.04661274328827858
# 3000 0.0313209593296051
# 4000 0.02348794788122177
# 5000 0.018753759562969208
# 6000 0.015592060983181
# 7000 0.013334563001990318
# 8000 0.011643558740615845
# 9000 0.010330350138247013
# 10000 0.009281625971198082
#
# Hypothesis:  [[0.02048131]
#  [0.99181914]
#  [0.9918208 ]
#  [0.99999857]]
# Correct:  [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Accuracy:  100.0 %

# %% [markdown]
# ## XOR

# %%
X = torch.FloatTensor([[0, 0], [0, 1], [1, 0], [1, 1]])
Y = torch.FloatTensor([[1], [0], [0], [1]])

linear = torch.nn.Linear(2, 1)
sigmoid = torch.nn.Sigmoid()

model = torch.nn.Sequential(linear, sigmoid)

criterion = torch.nn.BCELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

for step in range(10001):
    optimizer.zero_grad()
    hypothesis = model(X)

    # cost/loss function
    cost = criterion(hypothesis, Y)
    cost.backward()
    optimizer.step()

    if step % 1000 == 0:
        print(step, cost.item())
        
# Accuracy computation
# True if hypothesis>0.5 else False
with torch.no_grad():
    hypothesis = model(X)
    predicted = (hypothesis > 0.5).float()
    accuracy = (predicted == Y).float().mean()
    print('\nHypothesis: ', hypothesis.detach().cpu().numpy(), 
          '\nCorrect: ', predicted.detach().cpu().numpy(), 
          '\nAccuracy: ', accuracy.item() * 100, '%')
# Out:
# 0 0.7117056250572205
# 1000 0.6931472420692444
# 2000 0.6931471824645996
# 3000 0.6931471824645996
# 4000 0.6931471824645996
# 5000 0.6931471824645996
# 6000 0.6931471824645996
# 7000 0.6931471824645996
# 8000 0.6931471824645996
# 9000 0.6931471824645996
# 10000 0.6931471824645996
#
# Hypothesis:  [[0.5]
#  [0.5]
#  [0.5]
#  [0.5]]
# Correct:  [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Accuracy:  50.0 %

# %% [markdown]
# # XOR

# %% [markdown]
# XOR의 정확도를 어떻게 높일 수 있을까 ?

# %% [markdown]
# 이 문제를 **Multi layer perceptron**으로 해결하고자 하였다.

# %% [markdown]
# ## XOR_nn

# %%
X = torch.FloatTensor([[0, 0], [0, 1], [1, 0], [1, 1]]).to(device)
Y = torch.FloatTensor([[0], [1], [1], [0]]).to(device)

# nn layers
# multi layers
linear1 = torch.nn.Linear(2, 2, bias=True) 
linear2 = torch.nn.Linear(2, 1, bias=True)
sigmoid = torch.nn.Sigmoid()

# model
model = torch.nn.Sequential(linear1, sigmoid, linear2, sigmoid).to(device)


# define cost/loss & optimizer
criterion = torch.nn.BCELoss().to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=1)  # modified learning rate from 0.1 to 1

for step in range(10001):
    optimizer.zero_grad()
    hypothesis = model(X)

    # cost/loss function
    cost = criterion(hypothesis, Y)
    cost.backward()
    optimizer.step()

    if step % 1000 == 0:
        print(step, cost.item())
        
# Accuracy computation
# True if hypothesis>0.5 else False
with torch.no_grad():
    hypothesis = model(X)
    predicted = (hypothesis > 0.5).float()
    accuracy = (predicted == Y).float().mean()
    print('\nHypothesis: ', hypothesis.detach().cpu().numpy(), 
          '\nCorrect: ', predicted.detach().cpu().numpy(), 
          '\nAccuracy: ', accuracy.item() * 100, '%')
# Out:
# 0 0.698296844959259
# 1000 0.19452807307243347
# 2000 0.009715101681649685
# 3000 0.004814260173588991
# 4000 0.0031858349684625864
# 5000 0.0023765997029840946
# 6000 0.0018935836851596832
# 7000 0.0015729833394289017
# 8000 0.0013448038371279836
# 9000 0.0011741293128579855
# 10000 0.001041745999827981
#
# Hypothesis:  [[1.3386008e-03]
#  [9.9906665e-01]
#  [9.9906713e-01]
#  [9.5949002e-04]]
# Correct:  [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Accuracy:  100.0 %

# %% [markdown]
# ## XOR_nn.wide-deep

# %%
X = torch.FloatTensor([[0, 0], [0, 1], [1, 0], [1, 1]]).to(device)
Y = torch.FloatTensor([[0], [1], [1], [0]]).to(device)

# nn layers
# 10 : wide, layer 여러개 : deep
linear1 = torch.nn.Linear(2, 10, bias=True)
linear2 = torch.nn.Linear(10, 10, bias=True)
linear3 = torch.nn.Linear(10, 10, bias=True)
linear4 = torch.nn.Linear(10, 1, bias=True)
sigmoid = torch.nn.Sigmoid()

# model
model = torch.nn.Sequential(linear1, sigmoid, linear2, sigmoid, linear3, sigmoid, linear4, sigmoid).to(device)

# define cost/loss & optimizer
criterion = torch.nn.BCELoss().to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=1)  # modified learning rate from 0.1 to 1


for step in range(10001):
    optimizer.zero_grad()
    hypothesis = model(X)

    # cost/loss function
    cost = criterion(hypothesis, Y)
    cost.backward()
    optimizer.step()

    if step % 1000 == 0:
        print(step, cost.item())
# Out:
# 0 0.6988215446472168
# 1000 0.6931340098381042
# 2000 0.6931090354919434
# 3000 0.6930536031723022
# 4000 0.6927944421768188
# 5000 0.5020372867584229
# 6000 0.0008401497034355998
# 7000 0.00037353995139710605
# 8000 0.00023569058976136148
# 9000 0.0001708271011011675
# 10000 0.000133359688334167

# %% [markdown]
# 결과 : layer가 많고 깊어질수록 cost값이 많이 감소한다.

# %% [markdown]
# ## XOR_backpropagation

# %% [markdown]
# ### backpropagation

# %% [markdown]
# 내가 뽑고자하는 target값과 실제 모델이 계산한 output이 얼마나 차이나는지 구한 후, 그 오차값을 뒤로 전파해가며 각 노드의 변수를 갱신하는 알고리즘이다.
#
# 그렇다면,
#
# 1 ) 각 노드의 weight, bias 변수를 어떻게 update ?
#
# 2 ) Multi Layer Network에서 각 노드, 레이어의 변수들이 다른데 그 값을 얼만큼 변경하는지 어떻게 알 수 있는가 ?
#
# -------
#
# 다음의 수학적 방법을 사용하여 해결 가능하다.
# * Stochastic Gradient Descent
# * Chain Rule

# %% [markdown]
# #### Stochastic Gradient Descent

# %% [markdown]
# Loss function을 계산할 때 전체 Train-set을 사용하는 것을 Batch Gradient Descent라고 한다.
#
# 그러나 이렇게 계산하면, 한 번 step을 내딛을 때 전체 데이터에 대해 Loss Function을 계산해야하므로 너무 많은 계산양을 필요로 한다.
#
# 이를 방지하기 위해 보통 Stochastic Gradient Descent를 사용한다.
#
#
# 1 ) 다소 부정확하지만 속도가 훨씬 빨라 같은 시간에 더 많은 step을 갈 수 있다
#
# 2 ) 여러 번 반복할 경우 Batch Gradient Descent 처리 결과로 수렴한다.
#
# 3 ) Local Minima에 빠지지 않고 더 좋은 방향으로 수렴할 가능성이 높다
#
# 4 ) SGD를 변형시킨 알고리즘은 훨씬 좋은 성능을 낼 수 있다.
#
#     * Naive Stochastic Gradient Descent
#     * Momentum
#     * NAG
#     * Adagrad
#     * AdaDelta
#     * RMSprop

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Chain Rule

# %% [markdown]
# x가 변화했을 때 함수 g가 얼마나 변하는지,
#
# 함수 g의 변화로 인해 함수 f가 얼마나 변하는지,
#
# 함수 f의 인자가 함수 g이면 최종 값 F의 변화량에 기여하는 함수 f와 g의 기여도를 알 수 있다.
#
# ------------
# ------------
# **[ 정의 ]**
#
# $$ F = f(g(x)) = f * g $$ 로 정의된 합성함수이면 F는 미분 가능하다.
#
# 이 때, $$F'(x) = f'(g(x))*g'(x)$$
#
# $$ t = g(x) $$ 라고 가정한다면,
#
# $$ \frac {dy} {dx} = \frac{dt}{dx} * \frac{dy}{dt} $$ 가 성립된다.

# %% [markdown]
# ### 실습_sigmoid

# %%
def sigmoid(x) :
    return 1./ ( 1.0 + torch.exp(-x))

# sigmoid 미분한 뒤 함수
def sigmoid_prime(x) :
    return sigmoid(x) * ( 1- sigmoid(x))

# %%
X = torch.FloatTensor([[0, 0], [0, 1], [1, 0], [1, 1]]).to(device)
Y = torch.FloatTensor([[0], [1], [1], [0]]).to(device)

# nn layers
w1 = torch.Tensor(2, 2).to(device)
b1 = torch.Tensor(2).to(device)
w2 = torch.Tensor(2, 1).to(device)
b2 = torch.Tensor(1).to(device)

learning_rate = 0.0000001


for step in range(10001) :
    # forward
    l1 = torch.add(torch.matmul(X, w1), b1)
    a1 = sigmoid(l1)
    l2 = torch.add(torch.matmul(a1, w2), b2)
    Y_pred = sigmoid(l2)
    
    # binary sigmoid 함수
    cost = -torch.mean(Y * torch.log(Y_pred) + (1 - Y) * torch.log(1 - Y_pred) )
    
    # Back prop (chain rule)
    # Loss derivative
    d_Y_pred = (Y_pred - Y) / (Y_pred * (1.0 - Y_pred) + 1e-7)
    
    # layer 2
    d_l2 = d_Y_pred * sigmoid_prime(l2)
    d_b2 = d_l2
    d_w2 = torch.matmul(torch.transpose(a1, 0, 1), d_b2)
    
    # layer 1
    d_a1 = torch.matmul(d_b2, torch.transpose(w2, 0, 1))
    d_l1 = d_a1 * sigmoid_prime(l1)
    d_b1 = d_l1
    d_w1 = torch.matmul(torch.transpose(X, 0, 1), d_b1)
    
    # weight update
    w1 = w1 - learning_rate * d_w1
    b1 = b1 - learning_rate * torch.mean(d_b1, 0)
    w2 = w2 - learning_rate * d_w2
    b2 = b2 - learning_rate * torch.mean(d_b2, 0)
    
    if step % 1000 == 0 :
        print(step, cost.item())
# Out:
# 0 nan
# 1000 nan
# 2000 nan
# 3000 nan
# 4000 nan
# 5000 nan
# 6000 nan
# 7000 nan
# 8000 nan
# 9000 nan
# 10000 nan

# %% [markdown]
# ### 실습_relu

# %% [markdown]
# sigmoid 는 함수의 입출력 형태가 인간 뇌의 뉴런과 유사한 형태를 보여 많이 사용된 activation이지만 다음의 문제가 있다.
#
# 1 ) **Vanishing gradient**
#
# local gradient 값이 z=0.5일 때 최대값이 0.25를 가지게 된다. 이는 gradient signal이 sigmoid gate를 거칠때마다 최소한 1/4로 감소함을 의미한다.
#
# 따라서, 선행 layer는 후행 layer보다 훨씬 낮은 속도로 학습하게 된다.
#
# 2 ) **Non-zero centered**
#
# parameter의 gradient는 입력값(x)에 의해 영향을 받고, 입력값이 모두 양수일 경우 parameter의 부호는 모두 같게 된다. 이 경우, gradient descent가 정확한 방향으로 가지 못하고 지그재그로 발산하는 문제가 생긴다.
#
# 이러한 출력값은 다음 layer의 입력값이므로 함수값이 not-centered 특성을 가진 sigmoid는 성능에 좋지 않은 영향을 끼치게 된다.
#
# -------
#
# * 다른 활성함수
#
# 1 ) tanh
#
#     - 함수값을 [-1, 1] 로 제한
#     - zero-centered
#
# 2 ) relu(Rectified Linear Unit)
#
#     - f(x) = max(0, x) 로 표현 가능하고, x > 0 이면 기울기 =1 ,그 외에는 0
#     - SGD의 optimization 속도가 매우 빠름 ( 함수가 linear 하므로 )
#     - 미분값이 0 또는 1
#     - 단점 : x < 0 일 때, 기울기가 0이므로 뉴런이 죽어서 업데이트 수행 불가
